# %%
# read python libraries

import datetime, warnings, scipy 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.style as style
from matplotlib.patches import ConnectionPatch
from collections import OrderedDict
from matplotlib.gridspec import GridSpec
# from mpl_toolkits.basemap import Basemap

plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# # Load Data
#
# flights.csv is so large, so typical pandas read csv method is slow.
# By using map reduce model, a large csv file would be load in multiple chunks for speed and memory purpose

# %%
def process_chunk(df):
#     df = df.query('MONTH == "1"') 
    df.query("MONTH in ('1','7')")
#     print(df.shape)
    return df

# %%
chunks = pd.read_csv('input/flight-delays/flights.csv', chunksize=10000)

chunk_list = []                # used for storing dataframes
for chunk in chunks:           # each chunk is a dataframe    
    # perform data filtering 
    filtered_chunk = process_chunk(chunk)
    
    # Once the data filtering is done, append the filtered chunk to list
    chunk_list.append(filtered_chunk)

# concat all the dfs in the list into a single dataframe 
df = pd.concat(chunk_list)
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                    5          2354.0
# 1            LAX                 PBI                   10             2.0
# 2            SFO                 CLT                   20            18.0
# 3            LAX                 MIA                   20            15.0
# 4            SEA                 ANC                   25            24.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
# 3             -5.0      15.0        30.0           285.0         281.0
# 4             -1.0      11.0        35.0           235.0         215.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0                430         408.0
# 1     263.0      2330      737.0      4.0                750         741.0
# 2     266.0      2296      800.0     11.0                806         811.0
# 3     258.0      2342      748.0      8.0                805         756.0
# 4     199.0      1448      254.0      5.0                320         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN

# %%
df.describe()
# Out:
#            YEAR     MONTH            DAY    DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  469968.0  469968.0  469968.000000  469968.000000  469968.000000
# mean     2015.0       1.0      15.853001       4.025559    2266.351901
# std         0.0       0.0       8.952803       1.933772    1804.269617
# min      2015.0       1.0       1.000000       1.000000       1.000000
# 25%      2015.0       1.0       8.000000       2.000000     760.000000
# 50%      2015.0       1.0      16.000000       4.000000    1735.000000
# 75%      2015.0       1.0      24.000000       6.000000    3488.000000
# max      2015.0       1.0      31.000000       7.000000    9793.000000
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY       TAXI_OUT  \
# count        469968.000000   458311.000000    458311.000000  458092.000000
# mean           1323.513392     1333.028542         9.759471      16.456498
# std             468.146653      479.639617        36.636491       9.524406
# min               5.000000        1.000000       -48.000000       1.000000
# 25%             925.000000      930.000000        -5.000000      11.000000
# 50%            1320.000000     1328.000000        -2.000000      14.000000
# 75%            1720.000000     1729.000000         9.000000      19.000000
# max            2359.000000     2400.000000      1988.000000     176.000000
#
#           WHEELS_OFF  SCHEDULED_TIME   ELAPSED_TIME       AIR_TIME  \
# count  458092.000000   469968.000000  457013.000000  457013.000000
# mean     1356.753414      140.257754     136.491717     112.544096
# std       479.614158       74.862104      73.616901      71.682848
# min         1.000000       23.000000      17.000000       8.000000
# 25%       946.000000       85.000000      82.000000      60.000000
# 50%      1342.000000      122.000000     119.000000      94.000000
# 75%      1742.000000      173.000000     169.000000     144.000000
# max      2400.000000      718.000000     724.000000     676.000000
#
#             DISTANCE      WHEELS_ON        TAXI_IN  SCHEDULED_ARRIVAL  \
# count  469968.000000  457697.000000  457697.000000      469968.000000
# mean      803.261279    1486.618101       7.496929        1506.723902
# std       596.249383     499.447090       6.257324         483.556892
# min        31.000000       1.000000       1.000000           1.000000
# 25%       366.000000    1112.000000       4.000000        1124.000000
# 50%       641.000000    1517.000000       6.000000        1525.000000
# 75%      1046.000000    1909.000000       9.000000        1915.000000
# max      4983.000000    2400.000000     179.000000        2359.000000
#
#         ARRIVAL_TIME  ARRIVAL_DELAY       DIVERTED      CANCELLED  \
# count  457697.000000  457013.000000  469968.000000  469968.000000
# mean     1493.230865       5.813583       0.002070       0.025495
# std       502.957591      39.413501       0.045454       0.157624
# min         1.000000     -82.000000       0.000000       0.000000
# 25%      1117.000000     -13.000000       0.000000       0.000000
# 50%      1522.000000      -4.000000       0.000000       0.000000
# 75%      1915.000000      10.000000       0.000000       0.000000
# max      2400.000000    1971.000000       1.000000       1.000000
#
#        AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# count      95951.000000    95951.000000   95951.000000         95951.000000
# mean          13.319872        0.069827      17.802368            22.760211
# std           24.723111        2.068116      45.334536            40.939751
# min            0.000000        0.000000       0.000000             0.000000
# 25%            0.000000        0.000000       0.000000             0.000000
# 50%            4.000000        0.000000       2.000000             4.000000
# 75%           18.000000        0.000000      18.000000            29.000000
# max          830.000000      241.000000    1971.000000           948.000000
#
#        WEATHER_DELAY
# count   95951.000000
# mean        2.741889
# std        18.510443
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max       938.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469968 entries, 0 to 469967
# Data columns (total 31 columns):
# YEAR                   469968 non-null int64
# MONTH                  469968 non-null int64
# DAY                    469968 non-null int64
# DAY_OF_WEEK            469968 non-null int64
# AIRLINE                469968 non-null object
# FLIGHT_NUMBER          469968 non-null int64
# TAIL_NUMBER            467186 non-null object
# ORIGIN_AIRPORT         469968 non-null object
# DESTINATION_AIRPORT    469968 non-null object
# SCHEDULED_DEPARTURE    469968 non-null int64
# DEPARTURE_TIME         458311 non-null float64
# DEPARTURE_DELAY        458311 non-null float64
# TAXI_OUT               458092 non-null float64
# WHEELS_OFF             458092 non-null float64
# SCHEDULED_TIME         469968 non-null float64
# ELAPSED_TIME           457013 non-null float64
# AIR_TIME               457013 non-null float64
# DISTANCE               469968 non-null int64
# WHEELS_ON              457697 non-null float64
# TAXI_IN                457697 non-null float64
# SCHEDULED_ARRIVAL      469968 non-null int64
# ARRIVAL_TIME           457697 non-null float64
# ARRIVAL_DELAY          457013 non-null float64
# DIVERTED               469968 non-null int64
# CANCELLED              469968 non-null int64
# CANCELLATION_REASON    11982 non-null object
# AIR_SYSTEM_DELAY       95951 non-null float64
# SECURITY_DELAY         95951 non-null float64
# AIRLINE_DELAY          95951 non-null float64
# LATE_AIRCRAFT_DELAY    95951 non-null float64
# WEATHER_DELAY          95951 non-null float64
# dtypes: float64(16), int64(10), object(5)
# memory usage: 114.7+ MB

# %% [markdown]
# ## Data Cleaning
#
# ### 1. Dates and times
#
# In the initial dataframe, dates are coded according to 4 variables: `YEAR`, `MONTH`, `DAY`, and `DAY_OF_WEEK`. In fact, python offers the `datetime` format which is really convenient to work with dates and times and I thus convert the dates in this format:

# %%
df['DATE'] = pd.to_datetime(df[['YEAR', 'MONTH', 'DAY']])
df['DATE'].describe()
# Out:
# count                  469968
# unique                     31
# top       2015-01-02 00:00:00
# freq                    16741
# first     2015-01-01 00:00:00
# last      2015-01-31 00:00:00
# Name: DATE, dtype: object

# %% [markdown]
# Moreover, in the `SCHEDULED_DEPARTURE` variable, the hour of the take-off is coded as a float where the two first digits indicate the hour and the two last, the minutes. This format is not convenient and I thus convert it. Finally, I merge the take-off hour with the flight date. To proceed with these transformations, I define a few functions:

# %%
# Function that convert the 'HHMM' string to datetime.time
def format_hour(chain):
    if pd.isnull(chain):
        return np.nan
    else:
        if chain == 2400: chain = 0
        chain = "{0:04d}".format(int(chain))
        hour = datetime.time(int(chain[0:2]), int(chain[2:4]))
        return hour

# Function that combines a date and time to produce a datetime.datetime
def combine_date_hour(x):
    if pd.isnull(x[0]) or pd.isnull(x[1]):
        return np.nan
    else:
        return datetime.datetime.combine(x[0],x[1])

# Function that combine two columns of the dataframe to create a datetime format
def create_flight_time(df, col):    
    liste = []
    for index, cols in df[['DATE', col]].iterrows():    
        if pd.isnull(cols[1]):
            liste.append(np.nan)
        elif float(cols[1]) == 2400:
            cols[0] += datetime.timedelta(days=1)
            cols[1] = datetime.time(0,0)
            liste.append(combine_date_hour(cols))
        else:
            cols[1] = format_hour(cols[1])
            liste.append(combine_date_hour(cols))
    return pd.Series(liste)

# %%
df['SCHEDULED_DEPARTURE'] = create_flight_time(df, 'SCHEDULED_DEPARTURE')
df['DEPARTURE_TIME'] = df['DEPARTURE_TIME'].apply(format_hour)
df['SCHEDULED_ARRIVAL'] = df['SCHEDULED_ARRIVAL'].apply(format_hour)
df['ARRIVAL_TIME'] = df['ARRIVAL_TIME'].apply(format_hour)
#__________________________________________________________________________
df.loc[:5, ['SCHEDULED_DEPARTURE', 'SCHEDULED_ARRIVAL', 'DEPARTURE_TIME',
             'ARRIVAL_TIME', 'DEPARTURE_DELAY', 'ARRIVAL_DELAY']]
# Out:
#   SCHEDULED_DEPARTURE SCHEDULED_ARRIVAL DEPARTURE_TIME ARRIVAL_TIME  \
# 0 2015-01-01 00:05:00          04:30:00       23:54:00     04:08:00
# 1 2015-01-01 00:10:00          07:50:00       00:02:00     07:41:00
# 2 2015-01-01 00:20:00          08:06:00       00:18:00     08:11:00
# 3 2015-01-01 00:20:00          08:05:00       00:15:00     07:56:00
# 4 2015-01-01 00:25:00          03:20:00       00:24:00     02:59:00
# 5 2015-01-01 00:25:00          06:02:00       00:20:00     06:10:00
#
#    DEPARTURE_DELAY  ARRIVAL_DELAY
# 0            -11.0          -22.0
# 1             -8.0           -9.0
# 2             -2.0            5.0
# 3             -5.0           -9.0
# 4             -1.0          -21.0
# 5             -5.0            8.0

# %% [markdown]
# Note that in practice, the content of the `DEPARTURE_TIME` and `ARRIVAL_TIME` variables can be a bit misleading since they don't contain the dates. For exemple, in the first entry of the dataframe, the scheduled departure is at 0h05 the 1st of January. The `DEPARTURE_TIME` variable indicates 23h54 and we thus don't know if the flight leaved before time or if there was a large delay. Hence, the `DEPARTURE_DELAY` and `ARRIVAL_DELAY` variables proves more useful since they directly provides the delays in minutes. Hence, in what follows, I will not use the `DEPARTURE_TIME` and `ARRIVAL_TIME` variables.

# %% [markdown]
# ### 2. Mssing Values
# Finally, I clean the dataframe throwing the variables I won't use and re-organize the columns to ease its reading:

# %%
# variables_to_remove = ['TAXI_OUT', 'TAXI_IN', 'WHEELS_ON', 'WHEELS_OFF', 'YEAR', 
#                        'MONTH','DAY','DAY_OF_WEEK','DATE', 'AIR_SYSTEM_DELAY',
#                        'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY',
#                        'WEATHER_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#                        'FLIGHT_NUMBER', 'TAIL_NUMBER', 'AIR_TIME']
# df.drop(variables_to_remove, axis = 1, inplace = True)
# df = df[['AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#         'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
#         'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY',
#         'SCHEDULED_TIME', 'ELAPSED_TIME']]
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0            ANC                 SEA 2015-01-01 00:05:00       23:54:00
# 1            LAX                 PBI 2015-01-01 00:10:00       00:02:00
# 2            SFO                 CLT 2015-01-01 00:20:00       00:18:00
# 3            LAX                 MIA 2015-01-01 00:20:00       00:15:00
# 4            SEA                 ANC 2015-01-01 00:25:00       00:24:00
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
# 3             -5.0      15.0        30.0           285.0         281.0
# 4             -1.0      11.0        35.0           235.0         215.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0          04:30:00     04:08:00
# 1     263.0      2330      737.0      4.0          07:50:00     07:41:00
# 2     266.0      2296      800.0     11.0          08:06:00     08:11:00
# 3     258.0      2342      748.0      8.0          08:05:00     07:56:00
# 4     199.0      1448      254.0      5.0          03:20:00     02:59:00
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#         DATE
# 0 2015-01-01
# 1 2015-01-01
# 2 2015-01-01
# 3 2015-01-01
# 4 2015-01-01

# %% [markdown]
# At this stage, I examine how complete the dataset is:

# %%
pd.concat([df.isnull().sum(), 100 * df.isnull().sum()/len(df)], 
              axis=1).rename(columns={0:'Missing Records', 1:'Percentage (%)'})
# Out:
#                      Missing Records  Percentage (%)
# YEAR                               0        0.000000
# MONTH                              0        0.000000
# DAY                                0        0.000000
# DAY_OF_WEEK                        0        0.000000
# AIRLINE                            0        0.000000
# FLIGHT_NUMBER                      0        0.000000
# TAIL_NUMBER                     2782        0.591955
# ORIGIN_AIRPORT                     0        0.000000
# DESTINATION_AIRPORT                0        0.000000
# SCHEDULED_DEPARTURE                0        0.000000
# DEPARTURE_TIME                 11657        2.480382
# DEPARTURE_DELAY                11657        2.480382
# TAXI_OUT                       11876        2.526981
# WHEELS_OFF                     11876        2.526981
# SCHEDULED_TIME                     0        0.000000
# ELAPSED_TIME                   12955        2.756571
# AIR_TIME                       12955        2.756571
# DISTANCE                           0        0.000000
# WHEELS_ON                      12271        2.611029
# TAXI_IN                        12271        2.611029
# SCHEDULED_ARRIVAL                  0        0.000000
# ARRIVAL_TIME                   12271        2.611029
# ARRIVAL_DELAY                  12955        2.756571
# DIVERTED                           0        0.000000
# CANCELLED                          0        0.000000
# CANCELLATION_REASON           457986       97.450465
# AIR_SYSTEM_DELAY              374017       79.583504
# SECURITY_DELAY                374017       79.583504
# AIRLINE_DELAY                 374017       79.583504
# LATE_AIRCRAFT_DELAY           374017       79.583504
# WEATHER_DELAY                 374017       79.583504
# DATE                               0        0.000000

# %% [markdown]
# We see that the variables filling factor is quite good (> 97%). Since the scope of this work is not to idenfity delays pattern for possible improvement, I decide to proceed without trying to impute what's missing and I simply remove the entries that contain missing values.

# %%
# df.dropna(inplace = True)

# %% [markdown]
# ## Comparing airlines
#
# As said earlier, the `AIRLINE` variable contains the airline abreviations. Their full names can be retrieved from the airlines.csv file.

# %%
airlines_names = pd.read_csv('input/flight-delays/airlines.csv')
airlines_names
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
abbr_companies = airlines_names.set_index('IATA_CODE')['AIRLINE'].to_dict()

# %%
airports= pd.read_csv('input/flight-delays/airports.csv')
identify_airport = airports.set_index('IATA_CODE')['CITY'].to_dict()

# %% [markdown]
# ### 2.1 Basic statistical description of airlines
#
# As a first step, I consider all the flights from all carriers. Here, the aim is to classify the airlines with respect to their punctuality and for that purpose, I compute a few basic statisticial parameters:

# %%
airport_mean_delays = pd.DataFrame(pd.Series(df['ORIGIN_AIRPORT'].unique()))
airport_max_delays = pd.DataFrame(pd.Series(df['ORIGIN_AIRPORT'].unique()))

airport_mean_delays.set_index(0, drop = True, inplace = True)
airport_max_delays.set_index(0, drop = True, inplace = True)

# abbr_companies = airlines.set_index('IATA_CODE')['AIRLINE'].to_dict()
# identify_airport = airports.set_index('IATA_CODE')['CITY'].to_dict()
airlines_comparision = ["UA", "AA", "DL", "WN"]

# function that extract statistical parameters from a grouby objet:
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),
            'count': group.count(), 'mean': group.mean()}
#___________________________________________________________

for carrier in abbr_companies.keys():
    fg1 = df[df['AIRLINE'] == carrier]
    test = fg1['DEPARTURE_DELAY'].groupby(df['ORIGIN_AIRPORT']).apply(get_stats).unstack()
    airport_mean_delays[carrier] = test.loc[:, 'mean'] 
    airport_max_delays[carrier] = test.loc[:, 'max']

# %%
style.use('fivethirtyeight')
#_____________________________________________
# Function that define how delays are grouped
delay_type = lambda x:((0,1)[x > 5],2)[x > 45]
df['DELAY_LEVEL'] = df['DEPARTURE_DELAY'].apply(delay_type)
#____________________________________________________
fig = plt.figure(1, figsize=(10,7))
ax = sns.countplot(y="AIRLINE", hue='DELAY_LEVEL', data=df)
#____________________________________________________________________________________
# We replace the abbreviations by the full names of the companies and set the labels
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
plt.setp(ax.get_xticklabels(), fontsize=12, weight = 'bold', rotation = 0);
plt.setp(ax.get_yticklabels(), fontsize=12, weight = 'bold', rotation = 0);
ax.yaxis.label.set_visible(False)
plt.xlabel('Flight count', fontsize=16, weight = 'bold', labelpad=10)
#________________
# Set the legend
L = plt.legend()
L.get_texts()[0].set_text('on time (t < 5 min)')
L.get_texts()[1].set_text('small delay (5 < t < 45 min)')
L.get_texts()[2].set_text('large delay (t > 45 min)')
plt.show()

# %% [markdown]
# This figure gives a count of the delays of less than 5 minutes, those in the range 5 < t < 45 min and finally, the delays greater than 45 minutes. Hence, we wee that independently of the airline, delays greater than 45 minutes only account for a few percents. However, the proportion of delays in these three groups depends on the airline: as an exemple, in the case of United Airlines, the delays greater than 45 minutes are 2 times less frequent than delays in the range 5 < t < 45 min. Things are better for Southwest Airlines since delays greater than 45 minutes are 3 times less frequent than delays in the range 5 < t < 45 min.

# %%
fig = plt.figure(1, figsize=(12,12))

ax = fig.add_subplot(1,2,1)
subset = airport_mean_delays.iloc[:50,:].rename(columns = abbr_companies)
subset = subset.rename(index = identify_airport)
mask = subset.isnull()
sns.heatmap(subset, linewidths=0.05, cmap="Blues", mask=mask, vmin = 0, vmax = 30)
plt.setp(ax.get_xticklabels(), fontsize=12, rotation = 88) ;
ax.yaxis.label.set_visible(False)

ax = fig.add_subplot(1,2,2)    
subset = airport_mean_delays.iloc[50:100,:].rename(columns = abbr_companies)
subset = subset.rename(index = identify_airport)
fig.text(0.5, 1.02, "Scale of Delays from origin airport", ha='center', fontsize = 20)
mask = subset.isnull()
sns.heatmap(subset, linewidths=0.05, cmap="Blues", mask=mask, vmin = 0, vmax = 30)
plt.setp(ax.get_xticklabels(), fontsize=12, rotation = 88) ;
ax.yaxis.label.set_visible(False)

plt.tight_layout()

# %% [markdown]
# Looks like the airlines with most number of flights in 2015 are Southwest (1.2M flights - ranked No.1), Delta, American and Skywest, which also have relatively low cancellation rate. American Eagle has the highest cancellation rate - around 5%.
#
# Also, the divertation rate seems positively correlated with the flight volume. Overall the divertion rate is less than 1%.

# %% [markdown]
# ## UA 3 major hubs
# EWR, ORD, IAH

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 0            ANC                 SEA 2015-01-01 00:05:00       23:54:00
# 1            LAX                 PBI 2015-01-01 00:10:00       00:02:00
# 2            SFO                 CLT 2015-01-01 00:20:00       00:18:00
# 3            LAX                 MIA 2015-01-01 00:20:00       00:15:00
# 4            SEA                 ANC 2015-01-01 00:25:00       00:24:00
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
# 3             -5.0      15.0        30.0           285.0         281.0
# 4             -1.0      11.0        35.0           235.0         215.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0          04:30:00     04:08:00
# 1     263.0      2330      737.0      4.0          07:50:00     07:41:00
# 2     266.0      2296      800.0     11.0          08:06:00     08:11:00
# 3     258.0      2342      748.0      8.0          08:05:00     07:56:00
# 4     199.0      1448      254.0      5.0          03:20:00     02:59:00
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#         DATE  DELAY_LEVEL
# 0 2015-01-01            0
# 1 2015-01-01            0
# 2 2015-01-01            0
# 3 2015-01-01            0
# 4 2015-01-01            0

# %%
UA = df[df["AIRLINE"] == "UA"]
EWR =  UA["ORIGIN_AIRPORT"] == "EWR" 
ORD =  UA["ORIGIN_AIRPORT"] == "ORD"
IAH =  UA["ORIGIN_AIRPORT"] == "IAH"
majorHubs = UA[EWR | ORD | IAH]
sns.boxplot( x= majorHubs["ORIGIN_AIRPORT"], y= majorHubs["DEPARTURE_DELAY"], palette="Blues");
plt.show()

# %% [markdown]
# ### Routes with Max Departure Delay in major UA hubs

# %%
max_delay_route = {}
hub_codes = ["ORD", "EWR", "IAH"]

for hub_code in hub_codes:
    UA_hub = UA[UA["ORIGIN_AIRPORT"] == hub_code] 
    max_delay_ua = UA_hub["DEPARTURE_DELAY"].max()
    max_delay_route[hub_code] =  UA_hub[UA_hub["DEPARTURE_DELAY"] == max_delay_ua]#["DESTINATION_AIRPORT"]

# %%
max_delay_route['EWR']
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 116046  2015      1    8            4      UA           1565      N66057
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 116046            EWR                 IAH 2015-01-08 11:30:00       17:33:00
#
#         DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 116046            363.0      20.0      1753.0           246.0         226.0
#
#         AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 116046     192.0      1400     2005.0     14.0          14:36:00     20:19:00
#
#         ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 116046          343.0         0          0                 NaN
#
#         AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 116046               0.0             0.0          257.0                 86.0
#
#         WEATHER_DELAY       DATE  DELAY_LEVEL
# 116046            0.0 2015-01-08            2

# %%
max_delay_route['ORD']
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 101137  2015      1    7            3      UA           1436      N75435
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 101137            ORD                 DEN 2015-01-07 12:20:00       21:21:00
#
#         DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 101137            541.0      14.0      2135.0           162.0         142.0
#
#         AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 101137     119.0       888     2234.0      9.0          14:02:00     22:43:00
#
#         ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 101137          521.0         0          0                 NaN
#
#         AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 101137               0.0             0.0          145.0                376.0
#
#         WEATHER_DELAY       DATE  DELAY_LEVEL
# 101137            0.0 2015-01-07            2

# %%
max_delay_route['IAH']
# Out:
#         YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 174207  2015      1   12            1      UA           1558      N79011
#
#        ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 174207            IAH                 EWR 2015-01-12 10:30:00       18:04:00
#
#         DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 174207            454.0      32.0      1836.0           200.0         197.0
#
#         AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 174207     155.0      1400     2211.0     10.0          14:50:00     22:21:00
#
#         ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  \
# 174207          451.0         0          0                 NaN
#
#         AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 174207               0.0             0.0          451.0                  0.0
#
#         WEATHER_DELAY       DATE  DELAY_LEVEL
# 174207            0.0 2015-01-12            2

# %% [markdown]
# According to FAA, types of delay: https://aspm.faa.gov/aspmhelp/index/Types_of_Delay.html
#
# - Carrier Delay
#
# Carrier delay is within the control of the air carrier. Examples of occurrences that may determine carrier delay are: aircraft cleaning, aircraft damage, awaiting the arrival of connecting passengers or crew, baggage, bird strike, cargo loading, catering, computer, outage-carrier equipment, crew legality (pilot or attendant rest), damage by hazardous goods, engineering inspection, fueling, handling disabled passengers, late crew, lavatory servicing, maintenance, oversales, potable water servicing, removal of unruly passenger, slow boarding or seating, stowing carry-on baggage, weight and balance delays.
#
# - Late Arrival Delay
#
# Arrival delay at an airport due to the late arrival of the same aircraft at a previous airport. The ripple effect of an earlier delay at downstream airports is referred to as delay propagation.

# %%
UA["DELAY_LEVEL"].value_counts()
# Out:
# 0    23796
# 1    10885
# 2     3714
# Name: DELAY_LEVEL, dtype: int64

# %% [markdown]
# ## Data Trend

# %%
UA.head()
# Out:
#     YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 17  2015      1    1            4      UA           1197      N78448
# 25  2015      1    1            4      UA           1545      N76517
# 37  2015      1    1            4      UA           1528      N76519
# 49  2015      1    1            4      UA           1162      N37293
# 63  2015      1    1            4      UA           1500      N30401
#
#    ORIGIN_AIRPORT DESTINATION_AIRPORT SCHEDULED_DEPARTURE DEPARTURE_TIME  \
# 17            SFO                 IAH 2015-01-01 00:48:00       00:42:00
# 25            LAX                 IAH 2015-01-01 01:15:00       01:12:00
# 37            SJU                 EWR 2015-01-01 01:54:00       01:57:00
# 49            BQN                 EWR 2015-01-01 02:59:00       02:58:00
# 63            ORD                 IAH 2015-01-01 05:10:00       05:14:00
#
#     DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 17             -6.0      11.0        53.0           218.0         217.0
# 25             -3.0      11.0       123.0           183.0         175.0
# 37              3.0      12.0       209.0           255.0         241.0
# 49             -1.0      14.0       312.0           240.0         247.0
# 63              4.0      23.0       537.0           175.0         182.0
#
#     AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN SCHEDULED_ARRIVAL ARRIVAL_TIME  \
# 17     199.0      1635      612.0      7.0          06:26:00     06:19:00
# 25     156.0      1379      559.0      8.0          06:18:00     06:07:00
# 37     220.0      1608      449.0      9.0          05:09:00     04:58:00
# 49     225.0      1585      557.0      8.0          05:59:00     06:05:00
# 63     147.0       925      804.0     12.0          08:05:00     08:16:00
#
#     ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 17           -7.0         0          0                 NaN               NaN
# 25          -11.0         0          0                 NaN               NaN
# 37          -11.0         0          0                 NaN               NaN
# 49            6.0         0          0                 NaN               NaN
# 63           11.0         0          0                 NaN               NaN
#
#     SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 17             NaN            NaN                  NaN            NaN
# 25             NaN            NaN                  NaN            NaN
# 37             NaN            NaN                  NaN            NaN
# 49             NaN            NaN                  NaN            NaN
# 63             NaN            NaN                  NaN            NaN
#
#          DATE  DELAY_LEVEL
# 17 2015-01-01            0
# 25 2015-01-01            0
# 37 2015-01-01            0
# 49 2015-01-01            0
# 63 2015-01-01            0

# %%
UA["SCHEDULED_DEPARTURE"].dt.hour.plot.hist()

# %%
day = UA[UA['SCHEDULED_DEPARTURE'].dt.hour.between(7,19)]
night = UA[~UA['SCHEDULED_DEPARTURE'].dt.hour.between(7,19)]

# %%
plt.figure(figsize=(8,3))

# daytime
plt.subplot(1,2,1)
plt.hist(day['DEPARTURE_DELAY'])
plt.title('DEPARTURE_DELAY - Daytime')
plt.xlabel('DEPARTURE_DELAY')
plt.ylabel('Frequency')
plt.xlim([0,300])
plt.ylim([0,12000])

# nighttime
plt.subplot(1,2,2)
plt.hist(night['DEPARTURE_DELAY'])
plt.title('DEPARTURE_DELAY - Nighttime')
plt.xlabel('DEPARTURE_DELAY')
plt.ylabel('Frequency')
plt.xlim([0,300])
plt.ylim([0,12000])

plt.subplots_adjust(wspace=1, hspace=1)
plt.show()

# %%
day['hour'] = day['SCHEDULED_DEPARTURE'].dt.hour
weekdays = day.copy()[day['DAY_OF_WEEK'] <= 4] # 4 == Friday
weekends = day.copy()[day['DAY_OF_WEEK'] >= 5] # 5 == Saturday
by_hour_weekdays = weekdays.groupby('hour').mean()
by_hour_weekends = weekends.groupby('hour').mean()

print(by_hour_weekdays['DEPARTURE_DELAY'])
# Out:
# hour
# 7      7.344208
# 8      6.384894
# 9      9.320819
# 10    10.266390
# 11    14.568668
# 12    12.876969
# 13    14.344538
# 14    12.527586
# 15    14.365902
# 16    16.255794
# 17    16.602210
# 18    21.219488
# 19    19.260762
# Name: DEPARTURE_DELAY, dtype: float64

# %%
plt.figure(figsize=(8,3))

# weekdays
plt.subplot(1,2,1)
by_hour_weekdays['DEPARTURE_DELAY'].plot.line()
plt.title('DEPARTURE_DELAY - Weekdays')
plt.xlabel('Hour')
plt.ylabel('DEPARTURE_DELAY')
plt.xlim([7,17])
plt.ylim([0,30])

# weekends
plt.subplot(1,2,2)
by_hour_weekends['DEPARTURE_DELAY'].plot.line()
plt.title('DEPARTURE_DELAY - Weekends')
plt.xlabel('Hour')
plt.ylabel('DEPARTURE_DELAY')
plt.xlim([7,17])
plt.ylim([0,30])

plt.subplots_adjust(wspace=1, hspace=1)
plt.show()

# %%
day.corr()
# Out:
#                      YEAR  MONTH       DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# YEAR                  NaN    NaN       NaN          NaN            NaN
# MONTH                 NaN    NaN       NaN          NaN            NaN
# DAY                   NaN    NaN  1.000000    -0.030590       0.019570
# DAY_OF_WEEK           NaN    NaN -0.030590     1.000000      -0.012926
# FLIGHT_NUMBER         NaN    NaN  0.019570    -0.012926       1.000000
# DEPARTURE_DELAY       NaN    NaN -0.181334     0.040626       0.028318
# TAXI_OUT              NaN    NaN -0.025302    -0.034881      -0.063024
# WHEELS_OFF            NaN    NaN -0.041027     0.005386      -0.001734
# SCHEDULED_TIME        NaN    NaN -0.041553     0.029740       0.058579
# ELAPSED_TIME          NaN    NaN -0.067253     0.034335       0.054164
# AIR_TIME              NaN    NaN -0.055936     0.039000       0.057891
# DISTANCE              NaN    NaN -0.044015     0.032488       0.056409
# WHEELS_ON             NaN    NaN -0.010553     0.002065       0.038212
# TAXI_IN               NaN    NaN -0.099827    -0.003303       0.041120
# ARRIVAL_DELAY         NaN    NaN -0.202827     0.033249       0.018285
# DIVERTED              NaN    NaN -0.014097     0.000662       0.007866
# CANCELLED             NaN    NaN  0.143686    -0.143560      -0.000371
# AIR_SYSTEM_DELAY      NaN    NaN  0.000529    -0.009100      -0.049133
# SECURITY_DELAY        NaN    NaN  0.007565     0.016717       0.001641
# AIRLINE_DELAY         NaN    NaN -0.017063     0.021078      -0.005246
# LATE_AIRCRAFT_DELAY   NaN    NaN -0.069298     0.026717      -0.030257
# WEATHER_DELAY         NaN    NaN -0.064978    -0.035924      -0.005882
# DELAY_LEVEL           NaN    NaN -0.238465     0.071071       0.066405
# hour                  NaN    NaN -0.012630    -0.005026      -0.003928
#
#                      DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  \
# YEAR                             NaN       NaN         NaN             NaN
# MONTH                            NaN       NaN         NaN             NaN
# DAY                        -0.181334 -0.025302   -0.041027       -0.041553
# DAY_OF_WEEK                 0.040626 -0.034881    0.005386        0.029740
# FLIGHT_NUMBER               0.028318 -0.063024   -0.001734        0.058579
# DEPARTURE_DELAY             1.000000  0.099701    0.242872        0.031652
# TAXI_OUT                    0.099701  1.000000    0.000484        0.074523
# WHEELS_OFF                  0.242872  0.000484    1.000000       -0.054540
# SCHEDULED_TIME              0.031652  0.074523   -0.054540        1.000000
# ELAPSED_TIME                0.036345  0.163343   -0.063462        0.984695
# AIR_TIME                    0.021561  0.061127   -0.063645        0.992752
# DISTANCE                    0.028691  0.053981   -0.069069        0.976153
# WHEELS_ON                   0.088697 -0.014959    0.727493        0.088905
# TAXI_IN                     0.047737 -0.027146   -0.008895        0.006060
# ARRIVAL_DELAY               0.929656  0.275909    0.206880       -0.031243
# DIVERTED                    0.025511  0.014738    0.014869        0.015223
# CANCELLED                   0.065110 -0.000702    0.000718        0.023272
# AIR_SYSTEM_DELAY            0.052607  0.317117   -0.047296       -0.056312
# SECURITY_DELAY             -0.004431 -0.005535   -0.008092       -0.004241
# AIRLINE_DELAY               0.507769 -0.087772    0.064618        0.070000
# LATE_AIRCRAFT_DELAY         0.692155 -0.103227    0.238713       -0.025622
# WEATHER_DELAY               0.233145  0.143858    0.026885       -0.047952
# DELAY_LEVEL                 0.731714  0.113918    0.277217        0.051226
# hour                        0.114509 -0.043564    0.974831       -0.064954
#
#                      ELAPSED_TIME  AIR_TIME  DISTANCE  WHEELS_ON   TAXI_IN  \
# YEAR                          NaN       NaN       NaN        NaN       NaN
# MONTH                         NaN       NaN       NaN        NaN       NaN
# DAY                     -0.067253 -0.055936 -0.044015  -0.010553 -0.099827
# DAY_OF_WEEK              0.034335  0.039000  0.032488   0.002065 -0.003303
# FLIGHT_NUMBER            0.054164  0.057891  0.056409   0.038212  0.041120
# DEPARTURE_DELAY          0.036345  0.021561  0.028691   0.088697  0.047737
# TAXI_OUT                 0.163343  0.061127  0.053981  -0.014959 -0.027146
# WHEELS_OFF              -0.063462 -0.063645 -0.069069   0.727493 -0.008895
# SCHEDULED_TIME           0.984695  0.992752  0.976153   0.088905  0.006060
# ELAPSED_TIME             1.000000  0.990004  0.966517   0.091379  0.094735
# AIR_TIME                 0.990004  1.000000  0.977747   0.093758  0.001276
# DISTANCE                 0.966517  0.977747  1.000000   0.109313 -0.007012
# WHEELS_ON                0.091379  0.093758  0.109313   1.000000  0.006674
# TAXI_IN                  0.094735  0.001276 -0.007012   0.006674  1.000000
# ARRIVAL_DELAY            0.037550 -0.013945 -0.021828   0.082923  0.228911
# DIVERTED                      NaN       NaN  0.014960  -0.032095 -0.002415
# CANCELLED                     NaN       NaN  0.016217        NaN       NaN
# AIR_SYSTEM_DELAY         0.088960 -0.035900 -0.062188  -0.024099  0.462836
# SECURITY_DELAY          -0.003472 -0.002711 -0.003698  -0.005678  0.000313
# AIRLINE_DELAY            0.030274  0.057892  0.067031  -0.024246 -0.077877
# LATE_AIRCRAFT_DELAY     -0.060139 -0.041777 -0.021823   0.018320 -0.019055
# WEATHER_DELAY           -0.039071 -0.056723 -0.055035  -0.078352 -0.039467
# DELAY_LEVEL              0.055634  0.042233  0.045933   0.171152  0.021595
# hour                    -0.077614 -0.072583 -0.079619   0.723024 -0.016271
#
#                      ARRIVAL_DELAY  DIVERTED  CANCELLED  AIR_SYSTEM_DELAY  \
# YEAR                           NaN       NaN        NaN               NaN
# MONTH                          NaN       NaN        NaN               NaN
# DAY                      -0.202827 -0.014097   0.143686          0.000529
# DAY_OF_WEEK               0.033249  0.000662  -0.143560         -0.009100
# FLIGHT_NUMBER             0.018285  0.007866  -0.000371         -0.049133
# DEPARTURE_DELAY           0.929656  0.025511   0.065110          0.052607
# TAXI_OUT                  0.275909  0.014738  -0.000702          0.317117
# WHEELS_OFF                0.206880  0.014869   0.000718         -0.047296
# SCHEDULED_TIME           -0.031243  0.015223   0.023272         -0.056312
# ELAPSED_TIME              0.037550       NaN        NaN          0.088960
# AIR_TIME                 -0.013945       NaN        NaN         -0.035900
# DISTANCE                 -0.021828  0.014960   0.016217         -0.062188
# WHEELS_ON                 0.082923 -0.032095        NaN         -0.024099
# TAXI_IN                   0.228911 -0.002415        NaN          0.462836
# ARRIVAL_DELAY             1.000000       NaN        NaN          0.271823
# DIVERTED                       NaN  1.000000  -0.006389               NaN
# CANCELLED                      NaN -0.006389   1.000000               NaN
# AIR_SYSTEM_DELAY          0.271823       NaN        NaN          1.000000
# SECURITY_DELAY           -0.003515       NaN        NaN         -0.002557
# AIRLINE_DELAY             0.467981       NaN        NaN         -0.179474
# LATE_AIRCRAFT_DELAY       0.665174       NaN        NaN         -0.103430
# WEATHER_DELAY             0.254145       NaN        NaN         -0.012865
# DELAY_LEVEL               0.673729  0.028813  -0.110070         -0.071369
# hour                      0.079282  0.010246   0.010298         -0.073780
#
#                      SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# YEAR                            NaN            NaN                  NaN
# MONTH                           NaN            NaN                  NaN
# DAY                        0.007565      -0.017063            -0.069298
# DAY_OF_WEEK                0.016717       0.021078             0.026717
# FLIGHT_NUMBER              0.001641      -0.005246            -0.030257
# DEPARTURE_DELAY           -0.004431       0.507769             0.692155
# TAXI_OUT                  -0.005535      -0.087772            -0.103227
# WHEELS_OFF                -0.008092       0.064618             0.238713
# SCHEDULED_TIME            -0.004241       0.070000            -0.025622
# ELAPSED_TIME              -0.003472       0.030274            -0.060139
# AIR_TIME                  -0.002711       0.057892            -0.041777
# DISTANCE                  -0.003698       0.067031            -0.021823
# WHEELS_ON                 -0.005678      -0.024246             0.018320
# TAXI_IN                    0.000313      -0.077877            -0.019055
# ARRIVAL_DELAY             -0.003515       0.467981             0.665174
# DIVERTED                        NaN            NaN                  NaN
# CANCELLED                       NaN            NaN                  NaN
# AIR_SYSTEM_DELAY          -0.002557      -0.179474            -0.103430
# SECURITY_DELAY             1.000000      -0.006175            -0.005234
# AIRLINE_DELAY             -0.006175       1.000000            -0.071197
# LATE_AIRCRAFT_DELAY       -0.005234      -0.071197             1.000000
# WEATHER_DELAY             -0.002366      -0.108192             0.036101
# DELAY_LEVEL               -0.005395       0.318489             0.382730
# hour                      -0.007139      -0.047616             0.128800
#
#                      WEATHER_DELAY  DELAY_LEVEL      hour
# YEAR                           NaN          NaN       NaN
# MONTH                          NaN          NaN       NaN
# DAY                      -0.064978    -0.238465 -0.012630
# DAY_OF_WEEK              -0.035924     0.071071 -0.005026
# FLIGHT_NUMBER            -0.005882     0.066405 -0.003928
# DEPARTURE_DELAY           0.233145     0.731714  0.114509
# TAXI_OUT                  0.143858     0.113918 -0.043564
# WHEELS_OFF                0.026885     0.277217  0.974831
# SCHEDULED_TIME           -0.047952     0.051226 -0.064954
# ELAPSED_TIME             -0.039071     0.055634 -0.077614
# AIR_TIME                 -0.056723     0.042233 -0.072583
# DISTANCE                 -0.055035     0.045933 -0.079619
# WHEELS_ON                -0.078352     0.171152  0.723024
# TAXI_IN                  -0.039467     0.021595 -0.016271
# ARRIVAL_DELAY             0.254145     0.673729  0.079282
# DIVERTED                       NaN     0.028813  0.010246
# CANCELLED                      NaN    -0.110070  0.010298
# AIR_SYSTEM_DELAY         -0.012865    -0.071369 -0.073780
# SECURITY_DELAY           -0.002366    -0.005395 -0.007139
# AIRLINE_DELAY            -0.108192     0.318489 -0.047616
# LATE_AIRCRAFT_DELAY       0.036101     0.382730  0.128800
# WEATHER_DELAY             1.000000     0.144016  0.031961
# DELAY_LEVEL               0.144016     1.000000  0.164865
# hour                      0.031961     0.164865  1.000000

# %%
# dataplot = sns.heatmap(day.corr().iloc[15:], cmap="YlGnBu", annot=True)
# plt.show()

# %%
# sns.set_theme()
sns.relplot(data=day, x='hour', y='DEPARTURE_DELAY', size='WEATHER_DELAY', hue='AIRLINE_DELAY'      
           )
plt.ylim(0, 600) 
plt.xlim(7, 19) 
plt.show()
